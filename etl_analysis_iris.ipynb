# %%
from supabase import create_client
import pandas as pd, os
from dotenv import load_dotenv
load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
data = supabase.table("iris_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from supabase import create_client
#       2 import pandas as pd, os
#       3 from dotenv import load_dotenv
#
# ModuleNotFoundError: No module named 'supabase'

# %%
pip install supabase
# Out:
# Collecting supabase
#   Downloading supabase-2.25.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting realtime==2.25.0 (from supabase)
#   Downloading realtime-2.25.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting supabase-functions==2.25.0 (from supabase)
#   Downloading supabase_functions-2.25.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting storage3==2.25.0 (from supabase)
#   Downloading storage3-2.25.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting supabase-auth==2.25.0 (from supabase)
#   Downloading supabase_auth-2.25.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting postgrest==2.25.0 (from supabase)
#   Downloading postgrest-2.25.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx<0.29,>=0.26 (from supabase)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting deprecation>=2.1.0 (from postgrest==2.25.0->supabase)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic<3.0,>=1.9 (from postgrest==2.25.0->supabase)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting yarl>=1.20.1 (from postgrest==2.25.0->supabase)
#   Downloading yarl-1.22.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (75 kB)
# Collecting typing-extensions>=4.14.0 (from realtime==2.25.0->supabase)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting websockets<16,>=11 (from realtime==2.25.0->supabase)
#   Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting pyjwt>=2.10.1 (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting strenum>=0.4.15 (from supabase-functions==2.25.0->supabase)
#   Using cached StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Collecting anyio (from httpx<0.29,>=0.26->supabase)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<0.29,>=0.26->supabase) (2025.10.5)
# Collecting httpcore==1.* (from httpx<0.29,>=0.26->supabase)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from httpx<0.29,>=0.26->supabase) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<0.29,>=0.26->supabase)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.25.0->supabase)
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Downloading pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0,>=1.9->postgrest==2.25.0->supabase)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in /Users/apple/Library/Python/3.13/lib/python/site-packages (from deprecation>=2.1.0->postgrest==2.25.0->supabase) (25.0)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase)
#   Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting cffi>=2.0.0 (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase)
#   Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.25.0->supabase)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting multidict>=4.0 (from yarl>=1.20.1->postgrest==2.25.0->supabase)
#   Downloading multidict-6.7.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.1 (from yarl>=1.20.1->postgrest==2.25.0->supabase)
#   Downloading propcache-0.4.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (13 kB)
# Downloading supabase-2.25.0-py3-none-any.whl (16 kB)
# Downloading postgrest-2.25.0-py3-none-any.whl (21 kB)
# Downloading realtime-2.25.0-py3-none-any.whl (22 kB)
# Downloading storage3-2.25.0-py3-none-any.whl (26 kB)
# Downloading supabase_auth-2.25.0-py3-none-any.whl (48 kB)
# Downloading supabase_functions-2.25.0-py3-none-any.whl (8.5 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached h2-4.3.0-py3-none-any.whl (61 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.2 MB/s  0:00:01 eta 0:00:010m
# Using cached websockets-15.0.1-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading cryptography-46.0.3-cp311-abi3-macosx_10_9_universal2.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 840.2 kB/s  0:00:08 eta 0:00:01
# Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Using cached StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading yarl-1.22.0-cp313-cp313-macosx_11_0_arm64.whl (93 kB)
# Downloading multidict-6.7.0-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Downloading propcache-0.4.1-cp313-cp313-macosx_11_0_arm64.whl (46 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: strenum, websockets, typing-extensions, pyjwt, pycparser, propcache, multidict, hyperframe, hpack, h11, deprecation, anyio, annotated-types, yarl, typing-inspection, pydantic-core, httpcore, h2, cffi, pydantic, httpx, cryptography, realtime, supabase-functions, supabase-auth, storage3, postgrest, supabase
#   WARNING: The script websockets is installed in '/Library/Frameworks/Python.framework/Versions/3.13/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 19/28 [pydantic]]  WARNING: The script httpx is installed in '/Library/Frameworks/Python.framework/Versions/3.13/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28/28 [supabase]/28 [cryptography]
# Successfully installed annotated-types-0.7.0 anyio-4.12.0 cffi-2.0.0 cryptography-46.0.3 deprecation-2.1.0 h11-0.16.0 h2-4.3.0 hpack-4.1.0 httpcore-1.0.9 httpx-0.28.1 hyperframe-6.1.0 multidict-6.7.0 postgrest-2.25.0 propcache-0.4.1 pycparser-2.23 pydantic-2.12.5 pydantic-core-2.41.5 pyjwt-2.10.1 realtime-2.25.0 storage3-2.25.0 strenum-0.4.15 supabase-2.25.0 supabase-auth-2.25.0 supabase-functions-2.25.0 typing-extensions-4.15.0 typing-inspection-0.4.2 websockets-15.0.1 yarl-1.22.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from supabase import create_client
import pandas as pd, os
from dotenv import load_dotenv
load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
data = supabase.table("iris_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 from supabase import create_client
#       2 import pandas as pd, os
# ----> 3 from dotenv import load_dotenv
#       4 load_dotenv()
#       5 supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
pip install dotenv
# Out:
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Installing collected packages: python-dotenv, dotenv
#   WARNING: The script dotenv is installed in '/Library/Frameworks/Python.framework/Versions/3.13/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [dotenv]
# Successfully installed dotenv-0.9.9 python-dotenv-1.2.1
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from supabase import create_client
import pandas as pd, os
from dotenv import load_dotenv
load_dotenv()
supabase = create_client(os.getenv("SUPABASE_URL"), os.getenv("SUPABASE_KEY"))
data = supabase.table("iris_data").select("*").execute()
df = pd.DataFrame(data.data)
df.head()
df.info()
df.isnull().sum()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             150 non-null    int64
#  1   sepal_length   150 non-null    float64
#  2   sepal_width    150 non-null    float64
#  3   petal_length   150 non-null    float64
#  4   petal_width    150 non-null    float64
#  5   species        150 non-null    object
#  6   sepal_ratio    150 non-null    float64
#  7   petal_ratio    150 non-null    float64
#  8   is_petal_long  150 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 10.7+ KB
# Index(['id', 'sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species', 'sepal_ratio', 'petal_ratio', 'is_petal_long'],
#       dtype='object')
